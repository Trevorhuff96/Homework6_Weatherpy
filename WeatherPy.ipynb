# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ### Analysis:

# %% [markdown]
# -Based on the data regarding temperature and latitude, it is clear that there is a direct relationship between the two variables.
# The closer you get to the Equator (or 0 degrees latitude), the warmer the temperature becomes

# %% [markdown]
# -Although there isnt a direct correlation between Humidity and Latitude, the graph reveals a concentration of higher humidty
# percentages around the 0 degree latitude mark.

# %% [markdown]
# -At first glance there appears to be no relationship between latitude and cloudiness. However, there are several concentrated
# horizontal lines on the Latitude vs Cloudiness graph. The reason for this, I believe, is the fact that the cities that appear on
# each line together are most likely physically located near eachother, subsequently resulting in a common cloudiness percentage

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
subset_cities=cities[:10]

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"


# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
Processed_Cities= []
Cloudiness = []
Country = []
Date = [] 
Humidity = []   
Lat =[]       
Lng =[]         
MaxTemp =[]     
WindSpeed =[]

# %%
#use the subset to test data first

# %% [markdown]
# "coord":
# {"lon":145.77,"lat":-16.92},
# "weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}],
# "base":"cmc stations",
# "main":{"temp":293.25,"pressure":1019,"humidity":83,"temp_min":289.82,"temp_max":295.37},
# "wind":{"speed":5.1,"deg":150},
# "clouds":{"all":75},
# "rain":{"3h":3},
# "dt":1435658272,
# "sys":{"type":1,"id":8166,"message":0.0166,"country":"AU","sunrise":1435610796,"sunset":1435650870},
# "id":2172797,
# "name":"Cairns",
# "cod":200

# %%
counter=1
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        Cloudiness.append(response['clouds']['all'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        Humidity.append(response['main']['humidity'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        MaxTemp.append(response['main']['temp_max'])
        WindSpeed.append(response['wind']['speed'])
        print(f"Processing Record 1 ... |{city}")
        Processed_Cities.append(city)
        counter+=1
    except:
        print("City not found. Skipping...")
# Out:
# Processing Record 1 ... |hobyo
# Processing Record 1 ... |bandundu
# Processing Record 1 ... |pevek
# Processing Record 1 ... |new norfolk
# Processing Record 1 ... |dingle
# Processing Record 1 ... |port elizabeth
# Processing Record 1 ... |mendota
# City not found. Skipping...
# Processing Record 1 ... |bam
# Processing Record 1 ... |qaanaaq
# Processing Record 1 ... |stonehaven
# Processing Record 1 ... |tautira
# Processing Record 1 ... |saint george
# Processing Record 1 ... |pangnirtung
# Processing Record 1 ... |kholtoson
# Processing Record 1 ... |auki
# Processing Record 1 ... |luderitz
# Processing Record 1 ... |ilulissat
# Processing Record 1 ... |port shepstone
# Processing Record 1 ... |galiakot
# Processing Record 1 ... |grootfontein
# Processing Record 1 ... |half moon bay
# Processing Record 1 ... |acapulco
# Processing Record 1 ... |devarkonda
# Processing Record 1 ... |puerto ayora
# City not found. Skipping...
# Processing Record 1 ... |vilyuysk
# Processing Record 1 ... |cape town
# City not found. Skipping...
# Processing Record 1 ... |blagodatnoye
# Processing Record 1 ... |rikitea
# Processing Record 1 ... |avarua
# Processing Record 1 ... |busselton
# Processing Record 1 ... |atuona
# Processing Record 1 ... |jinka
# Processing Record 1 ... |ushuaia
# Processing Record 1 ... |touros
# Processing Record 1 ... |sao filipe
# City not found. Skipping...
# Processing Record 1 ... |albany
# City not found. Skipping...
# Processing Record 1 ... |utiel
# City not found. Skipping...
# Processing Record 1 ... |toumodi
# Processing Record 1 ... |tasiilaq
# Processing Record 1 ... |vaini
# Processing Record 1 ... |victoria
# Processing Record 1 ... |kodiak
# Processing Record 1 ... |maragogi
# Processing Record 1 ... |namibe
# Processing Record 1 ... |esperance
# Processing Record 1 ... |severo-kurilsk
# Processing Record 1 ... |souillac
# Processing Record 1 ... |fortuna
# Processing Record 1 ... |colmar
# Processing Record 1 ... |manati
# City not found. Skipping...
# Processing Record 1 ... |hermanus
# Processing Record 1 ... |hambantota
# Processing Record 1 ... |opuwo
# Processing Record 1 ... |upata
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 ... |srednekolymsk
# Processing Record 1 ... |saurimo
# Processing Record 1 ... |jamestown
# Processing Record 1 ... |corrales
# Processing Record 1 ... |paita
# Processing Record 1 ... |bemidji
# Processing Record 1 ... |geraldton
# Processing Record 1 ... |ust-kut
# Processing Record 1 ... |los llanos de aridane
# Processing Record 1 ... |vardo
# Processing Record 1 ... |muros
# Processing Record 1 ... |gonc
# Processing Record 1 ... |sao felix do xingu
# Processing Record 1 ... |saskylakh
# Processing Record 1 ... |punta arenas
# Processing Record 1 ... |shimoda
# Processing Record 1 ... |puerto quijarro
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 ... |chokurdakh
# Processing Record 1 ... |kamaishi
# Processing Record 1 ... |barrow
# Processing Record 1 ... |kindu
# Processing Record 1 ... |rocha
# Processing Record 1 ... |east london
# Processing Record 1 ... |hilo
# Processing Record 1 ... |cherrapunji
# Processing Record 1 ... |fairbanks
# Processing Record 1 ... |monterey
# City not found. Skipping...
# Processing Record 1 ... |tyret pervaya
# Processing Record 1 ... |hithadhoo
# Processing Record 1 ... |adrar
# Processing Record 1 ... |zhuhai
# Processing Record 1 ... |plettenberg bay
# Processing Record 1 ... |riyadh
# Processing Record 1 ... |saldanha
# Processing Record 1 ... |seydisehir
# City not found. Skipping...
# Processing Record 1 ... |pochutla
# Processing Record 1 ... |mataura
# Processing Record 1 ... |skibbereen
# Processing Record 1 ... |kahului
# Processing Record 1 ... |ixtapa
# Processing Record 1 ... |husavik
# Processing Record 1 ... |hasaki
# Processing Record 1 ... |karratha
# Processing Record 1 ... |port lincoln
# Processing Record 1 ... |bay roberts
# Processing Record 1 ... |hobart
# Processing Record 1 ... |torbay
# Processing Record 1 ... |lorengau
# Processing Record 1 ... |nikolskoye
# Processing Record 1 ... |saint-philippe
# Processing Record 1 ... |provideniya
# Processing Record 1 ... |port alfred
# Processing Record 1 ... |tuktoyaktuk
# Processing Record 1 ... |nelson bay
# Processing Record 1 ... |douglas
# Processing Record 1 ... |georgetown
# City not found. Skipping...
# Processing Record 1 ... |mandalgovi
# Processing Record 1 ... |sungaipenuh
# Processing Record 1 ... |buala
# Processing Record 1 ... |christchurch
# Processing Record 1 ... |isangel
# Processing Record 1 ... |butaritari
# Processing Record 1 ... |sibolga
# Processing Record 1 ... |upernavik
# Processing Record 1 ... |bethel
# Processing Record 1 ... |castro
# Processing Record 1 ... |ganzhou
# Processing Record 1 ... |arraial do cabo
# Processing Record 1 ... |vila velha
# City not found. Skipping...
# Processing Record 1 ... |norman wells
# Processing Record 1 ... |thompson
# Processing Record 1 ... |semnan
# Processing Record 1 ... |interlaken
# Processing Record 1 ... |biloela
# Processing Record 1 ... |mahebourg
# Processing Record 1 ... |mar del plata
# Processing Record 1 ... |sitka
# City not found. Skipping...
# Processing Record 1 ... |ponta do sol
# Processing Record 1 ... |klyuchi
# Processing Record 1 ... |port augusta
# Processing Record 1 ... |bela
# Processing Record 1 ... |brae
# Processing Record 1 ... |dikson
# Processing Record 1 ... |carnarvon
# Processing Record 1 ... |mbuyapey
# Processing Record 1 ... |verkhnevilyuysk
# Processing Record 1 ... |saint anthony
# Processing Record 1 ... |oriximina
# Processing Record 1 ... |podgorica
# Processing Record 1 ... |tucumcari
# Processing Record 1 ... |olga
# Processing Record 1 ... |chuy
# Processing Record 1 ... |bredasdorp
# Processing Record 1 ... |saint-joseph
# Processing Record 1 ... |pareora
# Processing Record 1 ... |hay river
# Processing Record 1 ... |lebu
# Processing Record 1 ... |tigil
# Processing Record 1 ... |sao gabriel da cachoeira
# Processing Record 1 ... |okoneshnikovo
# Processing Record 1 ... |saint-ambroise
# Processing Record 1 ... |sao joao da barra
# Processing Record 1 ... |bluff
# Processing Record 1 ... |kapaa
# Processing Record 1 ... |limbang
# Processing Record 1 ... |haines junction
# Processing Record 1 ... |gushikawa
# Processing Record 1 ... |dakar
# Processing Record 1 ... |tazovskiy
# Processing Record 1 ... |beberibe
# Processing Record 1 ... |kaitangata
# Processing Record 1 ... |cumberland
# Processing Record 1 ... |yarmouth
# Processing Record 1 ... |tuatapere
# Processing Record 1 ... |boende
# Processing Record 1 ... |tiksi
# City not found. Skipping...
# Processing Record 1 ... |sao geraldo do araguaia
# Processing Record 1 ... |nizhneudinsk
# City not found. Skipping...
# Processing Record 1 ... |mount isa
# Processing Record 1 ... |shubarshi
# Processing Record 1 ... |banjar
# Processing Record 1 ... |caravelas
# Processing Record 1 ... |latung
# Processing Record 1 ... |aklavik
# Processing Record 1 ... |jalu
# Processing Record 1 ... |ginda
# Processing Record 1 ... |faya
# City not found. Skipping...
# Processing Record 1 ... |altamont
# Processing Record 1 ... |bathsheba
# Processing Record 1 ... |tura
# Processing Record 1 ... |mount gambier
# Processing Record 1 ... |foxton
# Processing Record 1 ... |kaeo
# Processing Record 1 ... |sarangani
# Processing Record 1 ... |bilibino
# Processing Record 1 ... |rongcheng
# Processing Record 1 ... |airai
# Processing Record 1 ... |puerto cabezas
# Processing Record 1 ... |urdoma
# Processing Record 1 ... |sept-iles
# Processing Record 1 ... |praia
# Processing Record 1 ... |moron
# Processing Record 1 ... |edd
# Processing Record 1 ... |zhigansk
# Processing Record 1 ... |lashio
# Processing Record 1 ... |juliaca
# Processing Record 1 ... |ribeira grande
# Processing Record 1 ... |francisco sa
# Processing Record 1 ... |kroya
# Processing Record 1 ... |tucurui
# Processing Record 1 ... |leningradskiy
# Processing Record 1 ... |henties bay
# City not found. Skipping...
# Processing Record 1 ... |ljungby
# Processing Record 1 ... |yulara
# Processing Record 1 ... |martapura
# Processing Record 1 ... |sangar
# Processing Record 1 ... |liverpool
# Processing Record 1 ... |sungairaya
# Processing Record 1 ... |atambua
# Processing Record 1 ... |caarapo
# Processing Record 1 ... |oranjemund
# Processing Record 1 ... |roald
# Processing Record 1 ... |clarence town
# Processing Record 1 ... |ahipara
# Processing Record 1 ... |cabo san lucas
# Processing Record 1 ... |fergus falls
# Processing Record 1 ... |khasan
# Processing Record 1 ... |norsup
# Processing Record 1 ... |portmore
# Processing Record 1 ... |yakeshi
# Processing Record 1 ... |tripoli
# City not found. Skipping...
# Processing Record 1 ... |kattivakkam
# Processing Record 1 ... |kirovskiy
# Processing Record 1 ... |nanuque
# Processing Record 1 ... |lodingen
# City not found. Skipping...
# Processing Record 1 ... |george town
# City not found. Skipping...
# Processing Record 1 ... |primorskiy
# Processing Record 1 ... |padang
# Processing Record 1 ... |alnashi
# Processing Record 1 ... |sorong
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 ... |faanui
# Processing Record 1 ... |yinchuan
# Processing Record 1 ... |ancud
# Processing Record 1 ... |cottonwood
# Processing Record 1 ... |vestmanna
# Processing Record 1 ... |imbituba
# Processing Record 1 ... |mogadishu
# Processing Record 1 ... |vrangel
# Processing Record 1 ... |richards bay
# Processing Record 1 ... |ekhabi
# City not found. Skipping...
# Processing Record 1 ... |cherskiy
# Processing Record 1 ... |kamina
# Processing Record 1 ... |quimper
# Processing Record 1 ... |kathmandu
# City not found. Skipping...
# Processing Record 1 ... |tiarei
# City not found. Skipping...
# Processing Record 1 ... |tchamba
# Processing Record 1 ... |san quintin
# Processing Record 1 ... |poya
# Processing Record 1 ... |kungurtug
# Processing Record 1 ... |axim
# Processing Record 1 ... |tuy hoa
# Processing Record 1 ... |landerneau
# Processing Record 1 ... |san juan
# Processing Record 1 ... |inirida
# Processing Record 1 ... |portland
# Processing Record 1 ... |miraflores
# Processing Record 1 ... |dharchula
# City not found. Skipping...
# Processing Record 1 ... |cascais
# Processing Record 1 ... |atar
# Processing Record 1 ... |grindavik
# Processing Record 1 ... |ahuimanu
# Processing Record 1 ... |nerchinskiy zavod
# Processing Record 1 ... |nebolchi
# City not found. Skipping...
# Processing Record 1 ... |coahuayana
# Processing Record 1 ... |hami
# Processing Record 1 ... |kruisfontein
# Processing Record 1 ... |biak
# Processing Record 1 ... |bubaque
# Processing Record 1 ... |coihaique
# Processing Record 1 ... |ayan
# Processing Record 1 ... |meulaboh
# City not found. Skipping...
# Processing Record 1 ... |clovis
# Processing Record 1 ... |namatanai
# Processing Record 1 ... |constantine
# Processing Record 1 ... |syracuse
# Processing Record 1 ... |tonantins
# Processing Record 1 ... |puerto ayacucho
# Processing Record 1 ... |sandwick
# Processing Record 1 ... |kopervik
# Processing Record 1 ... |ust-koksa
# Processing Record 1 ... |yellowknife
# Processing Record 1 ... |marienburg
# City not found. Skipping...
# Processing Record 1 ... |ust-tsilma
# Processing Record 1 ... |grand forks
# City not found. Skipping...
# Processing Record 1 ... |dandong
# Processing Record 1 ... |robertsport
# Processing Record 1 ... |maues
# Processing Record 1 ... |shumskiy
# Processing Record 1 ... |mangai
# Processing Record 1 ... |zeya
# Processing Record 1 ... |helena
# City not found. Skipping...
# Processing Record 1 ... |chivay
# Processing Record 1 ... |longyearbyen
# Processing Record 1 ... |fayetteville
# Processing Record 1 ... |khatanga
# City not found. Skipping...
# Processing Record 1 ... |elizabethton
# Processing Record 1 ... |sika
# Processing Record 1 ... |nuevo progreso
# Processing Record 1 ... |moundsville
# Processing Record 1 ... |qeshm
# Processing Record 1 ... |bandiagara
# Processing Record 1 ... |olavarria
# Processing Record 1 ... |necochea
# Processing Record 1 ... |marzuq
# Processing Record 1 ... |karla
# Processing Record 1 ... |buta
# Processing Record 1 ... |marrakesh
# Processing Record 1 ... |haapiti
# Processing Record 1 ... |oudtshoorn
# Processing Record 1 ... |san rafael
# City not found. Skipping...
# Processing Record 1 ... |hamilton
# Processing Record 1 ... |verkhoyansk
# Processing Record 1 ... |scarborough
# Processing Record 1 ... |finschhafen
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 ... |te anau
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 ... |bambous virieux
# Processing Record 1 ... |quelimane
# Processing Record 1 ... |uyuni
# Processing Record 1 ... |joensuu
# Processing Record 1 ... |laa
# Processing Record 1 ... |sakaraha
# Processing Record 1 ... |mapiripan
# Processing Record 1 ... |belmonte
# Processing Record 1 ... |broken hill
# Processing Record 1 ... |bougouni
# Processing Record 1 ... |yumbe
# Processing Record 1 ... |pisco
# Processing Record 1 ... |alyangula
# Processing Record 1 ... |nam som
# Processing Record 1 ... |katsuura
# Processing Record 1 ... |beringovskiy
# Processing Record 1 ... |pangai
# Processing Record 1 ... |barda
# Processing Record 1 ... |changping
# City not found. Skipping...
# Processing Record 1 ... |werota
# Processing Record 1 ... |benguela
# Processing Record 1 ... |komsomolskiy
# City not found. Skipping...
# Processing Record 1 ... |ormara
# Processing Record 1 ... |sioux lookout
# Processing Record 1 ... |fougamou
# Processing Record 1 ... |byron bay
# Processing Record 1 ... |varkaus
# Processing Record 1 ... |alta floresta
# Processing Record 1 ... |loa janan
# Processing Record 1 ... |moose factory
# Processing Record 1 ... |zhezkazgan
# Processing Record 1 ... |mul
# Processing Record 1 ... |paranaiba
# City not found. Skipping...
# Processing Record 1 ... |vostok
# Processing Record 1 ... |salalah
# Processing Record 1 ... |nabire
# Processing Record 1 ... |burley
# Processing Record 1 ... |redlands
# Processing Record 1 ... |shingu
# Processing Record 1 ... |trelew
# City not found. Skipping...
# Processing Record 1 ... |yumen
# Processing Record 1 ... |tougan
# Processing Record 1 ... |nouadhibou
# Processing Record 1 ... |guiratinga
# Processing Record 1 ... |conde
# Processing Record 1 ... |quatre cocos
# Processing Record 1 ... |potosi
# Processing Record 1 ... |itarema
# Processing Record 1 ... |carutapera
# Processing Record 1 ... |rio real
# City not found. Skipping...
# Processing Record 1 ... |gillette
# City not found. Skipping...
# Processing Record 1 ... |cairns
# Processing Record 1 ... |seydi
# Processing Record 1 ... |monrovia
# Processing Record 1 ... |codrington
# Processing Record 1 ... |santiago del estero
# Processing Record 1 ... |camacha
# Processing Record 1 ... |nanortalik
# Processing Record 1 ... |constitucion
# Processing Record 1 ... |yashalta
# Processing Record 1 ... |broome
# Processing Record 1 ... |tokur
# Processing Record 1 ... |caohai
# Processing Record 1 ... |westport
# Processing Record 1 ... |xiantao
# Processing Record 1 ... |taltal
# Processing Record 1 ... |nishihara
# Processing Record 1 ... |ocos
# Processing Record 1 ... |victor harbor
# Processing Record 1 ... |severomuysk
# Processing Record 1 ... |shahrud
# Processing Record 1 ... |ondjiva
# Processing Record 1 ... |kavieng
# Processing Record 1 ... |cayenne
# Processing Record 1 ... |porto nacional
# Processing Record 1 ... |moussoro
# Processing Record 1 ... |bonavista
# Processing Record 1 ... |griffith
# Processing Record 1 ... |maningrida
# Processing Record 1 ... |port blair
# Processing Record 1 ... |seoul
# Processing Record 1 ... |iqaluit
# Processing Record 1 ... |homa bay
# Processing Record 1 ... |kirakira
# Processing Record 1 ... |tiznit
# Processing Record 1 ... |port-gentil
# Processing Record 1 ... |belgrade
# Processing Record 1 ... |laguna
# Processing Record 1 ... |muisne
# City not found. Skipping...
# Processing Record 1 ... |paamiut
# Processing Record 1 ... |kushiro
# Processing Record 1 ... |cap malheureux
# Processing Record 1 ... |zilair
# City not found. Skipping...
# Processing Record 1 ... |walvis bay
# Processing Record 1 ... |okha
# Processing Record 1 ... |nioro
# Processing Record 1 ... |rumoi
# Processing Record 1 ... |marsabit
# Processing Record 1 ... |maturin
# Processing Record 1 ... |chicama
# Processing Record 1 ... |yuncheng
# City not found. Skipping...
# Processing Record 1 ... |skjervoy
# Processing Record 1 ... |astana
# City not found. Skipping...
# Processing Record 1 ... |igarka
# Processing Record 1 ... |mezen
# City not found. Skipping...
# Processing Record 1 ... |palmira
# Processing Record 1 ... |bowen
# Processing Record 1 ... |santa lucia
# Processing Record 1 ... |nakusp
# Processing Record 1 ... |liepaja
# Processing Record 1 ... |skeldon
# Processing Record 1 ... |taoudenni
# City not found. Skipping...
# Processing Record 1 ... |nizwa
# Processing Record 1 ... |hihya
# Processing Record 1 ... |huntsville
# City not found. Skipping...
# Processing Record 1 ... |jacareacanga
# Processing Record 1 ... |jurm
# Processing Record 1 ... |launceston
# Processing Record 1 ... |guerrero negro
# Processing Record 1 ... |bossangoa
# Processing Record 1 ... |marfino
# Processing Record 1 ... |merauke
# Processing Record 1 ... |eureka
# Processing Record 1 ... |jizan
# Processing Record 1 ... |wuhu
# City not found. Skipping...
# Processing Record 1 ... |tecoanapa
# Processing Record 1 ... |lillooet
# City not found. Skipping...
# Processing Record 1 ... |sabang
# Processing Record 1 ... |ust-nera
# Processing Record 1 ... |kissidougou
# Processing Record 1 ... |luanda
# Processing Record 1 ... |kjopsvik
# Processing Record 1 ... |klaksvik
# City not found. Skipping...
# Processing Record 1 ... |loja
# Processing Record 1 ... |banda aceh
# Processing Record 1 ... |kununurra
# Processing Record 1 ... |san patricio
# Processing Record 1 ... |cerrito
# Processing Record 1 ... |talnakh
# Processing Record 1 ... |viedma
# Processing Record 1 ... |talakan
# Processing Record 1 ... |gawler
# Processing Record 1 ... |sajanan
# Processing Record 1 ... |rudnogorsk
# Processing Record 1 ... |abnub
# Processing Record 1 ... |hienghene
# Processing Record 1 ... |maraa
# Processing Record 1 ... |san miguel
# Processing Record 1 ... |vikulovo
# Processing Record 1 ... |dunedin
# Processing Record 1 ... |pierre
# Processing Record 1 ... |praya
# Processing Record 1 ... |prainha
# Processing Record 1 ... |waipawa
# Processing Record 1 ... |egvekinot
# Processing Record 1 ... |mayachnyy
# Processing Record 1 ... |payson
# Processing Record 1 ... |kieta
# Processing Record 1 ... |yeniseysk
# Processing Record 1 ... |mende
# Processing Record 1 ... |lavrentiya
# Processing Record 1 ... |dali
# City not found. Skipping...
# Processing Record 1 ... |dzhebariki-khaya
# City not found. Skipping...
# Processing Record 1 ... |san ramon de la nueva oran
# Processing Record 1 ... |shakawe
# Processing Record 1 ... |saint-augustin
# Processing Record 1 ... |comodoro rivadavia
# Processing Record 1 ... |champerico
# Processing Record 1 ... |tanabi
# Processing Record 1 ... |nome
# Processing Record 1 ... |chifeng
# Processing Record 1 ... |gambo
# Processing Record 1 ... |grand gaube
# Processing Record 1 ... |saint-leu
# Processing Record 1 ... |angoche
# City not found. Skipping...
# Processing Record 1 ... |palora
# Processing Record 1 ... |singosari
# Processing Record 1 ... |college
# Processing Record 1 ... |valle hermoso
# Processing Record 1 ... |balkhash
# Processing Record 1 ... |wanning
# Processing Record 1 ... |sattahip
# Processing Record 1 ... |kinston
# Processing Record 1 ... |turukhansk
# Processing Record 1 ... |mehamn
# Processing Record 1 ... |kupang
# Processing Record 1 ... |jaragua do sul
# Processing Record 1 ... |margate
# Processing Record 1 ... |vestnes
# Processing Record 1 ... |kondinskoye
# Processing Record 1 ... |naze
# City not found. Skipping...
# Processing Record 1 ... |naryan-mar
# Processing Record 1 ... |port hardy
# Processing Record 1 ... |la ronge
# Processing Record 1 ... |tual
# Processing Record 1 ... |kindersley
# Processing Record 1 ... |bria
# Processing Record 1 ... |puteyets
# Processing Record 1 ... |muswellbrook
# Processing Record 1 ... |cam ranh

# %%
print(len(Processed_Cities), len(Cloudiness), len(Country), len(Date), len(WindSpeed))

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df= pd.DataFrame(
    {"City" : Processed_Cities,
    "Cloudiness" : Cloudiness,
    "Country" : Country,
    "Date" : Date,
    "Humidity" : Humidity,
    "Lat" : Lat,
    "Lng" : Lng,
    "Max Temp" : MaxTemp,
    "Wind Speed": WindSpeed,
    }
    )

# %%
weather_df.head()

# %%
weather_df.to_csv('output_data_file')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(x=weather_df['Lat'],y=weather_df['Max Temp'],
            c='xkcd:sky blue',alpha=.8, linewidths=2)
plt.title("Latitude vs. Temperature Plot (10/11/2018)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig('Latitude_vs_Temperature Plot_10_11_2018.png')

# %%
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(x=weather_df['Lat'],y=weather_df['Humidity'],
            c='xkcd:sky blue',alpha=.8, linewidths=2)
plt.title("Humidity vs Latitude Plot (10/11/2018)")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.savefig('Humidity_vs_LatitudePlot_10_11_2018.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(x=weather_df['Lat'],y=weather_df['Cloudiness'],
            c='xkcd:sky blue',alpha=.8, linewidths=2)
plt.title("Cloudiness vs. Latitude Plot (10/11/2018)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.savefig('Cloudiness_vs_LatitudePlot_10_11_2018.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(x=weather_df['Lat'],y=weather_df['Wind Speed'],
            c='xkcd:sky blue',alpha=.8, linewidths=2)
plt.title("Windspeed vs. Latitude Plot (10/11/2018)")
plt.xlabel("Latitude")
plt.ylabel("Windspeed(mph)")
plt.savefig('Windspeed_vs_LatitudePlot_10_11_2018.png')
plt.show()
